# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKumarBaitha320/Data-Science/blob/main/Pandas_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_public.csv',index_col='Respondent')
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# Filtering respodents from Nepal

df['Country']=='Nepal'
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: Country, Length: 88883, dtype: bool

# %%
# Count the value of nepal
(df['Country']=='Nepal').value_counts()
# Out:
# Country
# False    88646
# True       237
# Name: count, dtype: int64

# %%
# getting Nepal DATA FRAME
# df.loc[df['Country']=='Nepal']
df[df['Country']=='Nepal']
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
filter_nepal=df['Country']=='Nepal'
df[filter_nepal]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
# Another way through loc
df.loc[filter_nepal]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
df.loc[df['Country']=='Nepal']
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 508         I am a student who is learning to code      Yes
# 592                 I am a developer by profession      Yes
# 984                 I am a developer by profession      Yes
# 1355                I am a developer by profession      Yes
# 1783                I am a developer by profession      Yes
# ...                                            ...      ...
# 86618               I am a developer by profession      Yes
# 86742               I am a developer by profession      Yes
# 87231               I am a developer by profession      Yes
# 87568               I am a developer by profession      Yes
# 88543               I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 508                                                     Never
# 592                                                     Never
# ...

# %%
''' what nepali think of their managers?'''
# MgrIdiot
df.loc[filter_nepal,'MgrIdiot']
# Out:
# Respondent
# 508                         NaN
# 592                         NaN
# 984          Somewhat confident
# 1355         Somewhat confident
# 1783       Not at all confident
#                   ...
# 86618      Not at all confident
# 86742        Somewhat confident
# 87231    I don't have a manager
# 87568        Somewhat confident
# 88543        Somewhat confident
# Name: MgrIdiot, Length: 237, dtype: object

# %%
df.loc[filter_nepal,'MgrIdiot'].value_counts()
# Out:
# MgrIdiot
# Somewhat confident        66
# Very confident            28
# Not at all confident      23
# I don't have a manager     9
# Name: count, dtype: int64

# %%
df.loc[filter_nepal,'MgrIdiot'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='MgrIdiot'>

# %%
df.loc[filter_nepal,'MgrIdiot'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
# using and operator for multiple queries
# who are the nepalese who think their manager is actually idiot?
filter_idiot=(df['Country']=='Nepal') & (df['MgrIdiot']=='Not at all confident')
df.loc[filter_idiot]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 1783        I am a developer by profession      Yes
# 4452        I am a developer by profession      Yes
# 8392        I am a developer by profession       No
# 8751        I am a developer by profession      Yes
# 9860        I am a developer by profession      Yes
# 12222       I am a developer by profession      Yes
# 16498       I am a developer by profession      Yes
# 25984       I am a developer by profession      Yes
# 29157       I am a developer by profession      Yes
# 32610       I am a developer by profession      Yes
# 40608       I am a developer by profession      Yes
# 41114       I am a developer by profession      Yes
# 52045       I am a developer by profession      Yes
# 60493       I am a developer by profession      Yes
# 61164          I code primarily as a hobby      Yes
# 63653       I am a developer by profession      Yes
# 68293       I am a developer by profession      Yes
# ...

# %%
filter_idiot=(df['Country']=='Nepal') & (df['MgrIdiot']=='Not at all confident')
df.loc[filter_idiot].value_counts()
# Out:
# MainBranch                      Hobbyist  OpenSourcer                                         OpenSource                                                                       Employment          Country  Student  EdLevel                                   UndergradMajor                                                      EduOther                                                                                                                                                                                                                                                                            OrgSize               DevType                                                                                YearsCode  Age1stCode  YearsCodePro  CareerSat                           JobSat                              MgrIdiot              MgrMoney  MgrWant   JobSeek                                                       LastHireDate   LastInt                                                       
# ...

# %%
df.loc[filter_idiot,'ConvertedComp']
# Out:
# Respondent
# 1783      1692.0
# 4452         NaN
# 8392         NaN
# 8751         NaN
# 9860         NaN
# 12222        NaN
# 16498     1584.0
# 25984        NaN
# 29157     6852.0
# 32610     6324.0
# 40608     3168.0
# 41114     4992.0
# 52045     8436.0
# 60493        NaN
# 61164        NaN
# 63653        NaN
# 68293     4224.0
# 70768        NaN
# 73700     2220.0
# 79094     8788.0
# 81976     5268.0
# 84947     3696.0
# 86618    12000.0
# Name: ConvertedComp, dtype: float64

# %%
df.loc[filter_idiot,'ConvertedComp'].mean()
# Out:
# np.float64(5326.461538461538)

# %%
df.loc[filter_idiot,'ConvertedComp'].median()
# Out:
# 4992.0

# %%
df.loc[filter_idiot,'ConvertedComp'].sum()
# Out:
# np.float64(69244.0)

# %%
'''Welcome change?
Extract the QuestionText of the index called WelcomeChange from schema_df.
Display the WelcomeChange column from original dataframe df.
From our original dataframe df, find the value_counts() of WelcomeChange
Show the bar graph plot'''

schema_df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_schema.csv')
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
df['WelcomeChange'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='WelcomeChange'>

# %%
df['WelcomeChange'].value_counts()
# Out:
# WelcomeChange
# Just as welcome now as I felt last year                    62661
# Somewhat more welcome now than last year                    8853
# A lot more welcome now than last year                       4808
# Somewhat less welcome now than last year                    4259
# Not applicable - I did not use Stack Overflow last year     2675
# A lot less welcome now than last year                       2599
# Name: count, dtype: int64

# %%
schema_df.loc['WelcomeChange','QuestionText']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2023447635.py in <cell line: 0>()
# ----> 1 schema_df.loc['WelcomeChange','QuestionText']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4219             #  results if our categories are integers that dont match our codes
#    4220             # IntervalIndex: IntervalTree has no get_loc
# -> 4221             row = self.index.get_loc(index)
# ...

# %%
df['WelcomeChange']
# Out:
# Respondent
# 1         Just as welcome now as I felt last year
# 2         Just as welcome now as I felt last year
# 3         Just as welcome now as I felt last year
# 4         Just as welcome now as I felt last year
# 5         Just as welcome now as I felt last year
#                            ...
# 88377                                         NaN
# 88601                                         NaN
# 88802                                         NaN
# 88816                                         NaN
# 88863    Somewhat less welcome now than last year
# Name: WelcomeChange, Length: 88883, dtype: object

# %%
schema_df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_schema.csv' ,index_col='Column')
schema_df.info()
schema_df.loc['WelcomeChange','QuestionText']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Respondent to SurveyEase
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   QuestionText  85 non-null     object
# dtypes: object(1)
# memory usage: 1.3+ KB
# 'Compared to last year, how welcome do you feel on Stack Overflow?'

# %%
df['WelcomeChange']
# Out:
# Respondent
# 1         Just as welcome now as I felt last year
# 2         Just as welcome now as I felt last year
# 3         Just as welcome now as I felt last year
# 4         Just as welcome now as I felt last year
# 5         Just as welcome now as I felt last year
#                            ...
# 88377                                         NaN
# 88601                                         NaN
# 88802                                         NaN
# 88816                                         NaN
# 88863    Somewhat less welcome now than last year
# Name: WelcomeChange, Length: 88883, dtype: object

# %%
'''High salary Nepalese
Doing multiple queries?
Filter the respondents who are from Nepal and whose salary is greater than 10000. (Hint: ConvertedComp column.)
What is their Employment type and display their value_counts? (Hint: Column name is Employment)'''

df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
filter_highSalary=(df['Country']=='Nepal') & (df['ConvertedComp']>10000)
df.loc[filter_highSalary,'Employment']
# Out:
# 5968     Independent contractor, freelancer, or self-em...
# 25114    Independent contractor, freelancer, or self-em...
# 25897                                   Employed full-time
# 39282    Independent contractor, freelancer, or self-em...
# 40383                                   Employed full-time
# 42801    Independent contractor, freelancer, or self-em...
# 54821                                   Employed full-time
# 61281                                   Employed full-time
# 63428                                   Employed full-time
# 77455                                   Employed full-time
# 78532                                   Employed full-time
# 81604                                   Employed full-time
# 84918    Independent contractor, freelancer, or self-em...
# 86082                                   Employed full-time
# Name: Employment, dtype: object

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed full-time                                      64440
# Independent contractor, freelancer, or self-employed     8511
# Not employed, but looking for work                       5600
# Employed part-time                                       4469
# Not employed, and not looking for work                   3803
# Retired                                                   358
# Name: count, dtype: int64

# %%
'''
Homework
What are Nepali people using as tech stack?
Hint: Check LanguageWorkedWith in schema_df to know more.
Language + Salary
Show the LanguageWorkedWith,ConvertedComp info of developers of Nepal.
Python users from Nepal
'''
schema_df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_schema.csv')
schema_df.loc['Language','QuestionText']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3603688551.py in <cell line: 0>()
#       8 '''
#       9 schema_df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_schema.csv')
# ---> 10 schema_df.loc['Language','QuestionText']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4219             #  results if our categories are integers that dont match our codes
# ...
