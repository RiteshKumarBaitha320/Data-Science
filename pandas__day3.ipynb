# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshKumarBaitha320/Data-Science/blob/main/pandas__day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[1]
# Out:
# Respondent                                                      2
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                       No
# OpenSourcer                               Less than once per year
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 85, dtype: object

# %%
df.loc[1:3] #it prints 3 rows and whole columns
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
#
#                OpenSourcer                                         OpenSource  \
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
# 3                    Never  The quality of OSS and closed source software ...
#
#                            Employment                 Country         Student  \
# 1  Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time
# 2                  Employed full-time                Thailand              No
# 3                  Employed full-time           United States              No
#
# ...

# %%
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.loc[1]
# Out:
# Respondent                                                      2
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                       No
# OpenSourcer                               Less than once per year
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 85, dtype: object

# %%
df.loc[11]
# Out:
# Respondent                                                     12
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                       No
# OpenSourcer                                                 Never
# OpenSource      OSS is, on average, of HIGHER quality than pro...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                             Black or of African descent
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                                                   Easy
# Name: 11, Length: 85, dtype: object

# %%
df.loc[:,"Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.loc[:,"Hobbyist":"Employment"]
# Out:
#       Hobbyist                                        OpenSourcer  \
# 0          Yes                                              Never
# 1           No                            Less than once per year
# 2          Yes                                              Never
# 3           No                                              Never
# 4          Yes                         Once a month or more often
# ...        ...                                                ...
# 88878      Yes  Less than once a month but more than once per ...
# 88879       No                                              Never
# 88880       No                                              Never
# 88881       No                                              Never
# 88882      Yes                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# ...

# %%
df.loc[0:2,"Hobbyist":"Employment"]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
df.loc[0:1]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor  ...                            WelcomeChange  \
# ...

# %%
# select rows and column
df.loc[1:3,["Hobbyist","OpenSourcer"]]
# Out:
#   Hobbyist              OpenSourcer
# 1       No  Less than once per year
# 2      Yes                    Never
# 3       No                    Never

# %%
# 5️⃣ Conditional Selection (Very Important )
df.loc[df["Age"]>20,["MainBranch","Hobbyist","Age"]]
# Out:
#                                               MainBranch Hobbyist   Age
# 2      I am not primarily a developer, but I write co...      Yes  28.0
# 3                         I am a developer by profession       No  22.0
# 4                         I am a developer by profession      Yes  30.0
# 5      I am not primarily a developer, but I write co...      Yes  28.0
# 6                         I am a developer by profession       No  42.0
# ...                                                  ...      ...   ...
# 88866                                                NaN      Yes  30.0
# 88870                                                NaN      Yes  59.0
# 88871                                                NaN      Yes  21.0
# 88872                                                NaN      Yes  25.0
# 88876                                                NaN       No  40.0
#
# [72227 rows x 3 columns]

# %%
# # 5️⃣ Conditional Selection (Very Important )
df.loc[df["Hobbyist"]=="Yes",["MainBranch","Hobbyist","Age"]]
# Out:
#                                               MainBranch Hobbyist   Age
# 0                 I am a student who is learning to code      Yes  14.0
# 2      I am not primarily a developer, but I write co...      Yes  28.0
# 4                         I am a developer by profession      Yes  30.0
# 5      I am not primarily a developer, but I write co...      Yes  28.0
# 7                            I code primarily as a hobby      Yes  24.0
# ...                                                  ...      ...   ...
# 88872                                                NaN      Yes  25.0
# 88875                                                NaN      Yes   NaN
# 88877                                                NaN      Yes   NaN
# 88878                                                NaN      Yes   NaN
# 88882                                                NaN      Yes  18.0
#
# [71257 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df.shape
# Out:
# (88883, 85)

# %%
df[["Hobbyist"]]
# Out:
#       Hobbyist
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4          Yes
# ...        ...
# 88878      Yes
# 88879       No
# 88880       No
# 88881       No
# 88882      Yes
#
# [88883 rows x 1 columns]

# %%
df.loc[1]
# Out:
# Respondent                                                      2
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                       No
# OpenSourcer                               Less than once per year
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 1, Length: 85, dtype: object

# %%
df[["Hobbyist"]]
# Out:
#       Hobbyist
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4          Yes
# ...        ...
# 88878      Yes
# 88879       No
# 88880       No
# 88881       No
# 88882      Yes
#
# [88883 rows x 1 columns]

# %%
df.value_counts("Hobbyist")
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df["Hobbyist"].value_counts(normalize=True)*100
# Out:
# Hobbyist
# Yes    80.169436
# No     19.830564
# Name: proportion, dtype: float64

# %%
df[["Hobbyist",'Student']].apply(pd.Series.value_counts) #more than one columns
# Out:
#                 Hobbyist  Student
# No               17626.0  65816.0
# Yes              71257.0      NaN
# Yes, full-time       NaN  15769.0
# Yes, part-time       NaN   5429.0

# %%
# loc and iloc
df.loc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.loc[0:,"Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.loc[[0,1,2],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
# print the hobbyist value from 0 to 100
df.loc[0:100,'Hobbyist']
# Out:
# 0      Yes
# 1       No
# 2      Yes
# 3       No
# 4      Yes
#       ...
# 96     Yes
# 97     Yes
# 98     Yes
# 99     Yes
# 100    Yes
# Name: Hobbyist, Length: 101, dtype: object

# %%
# print the hobbyist to employement values of the 0 to 100 index data
df.loc[0:100,['Hobbyist','Employment']]
# Out:
#     Hobbyist                                         Employment
# 0        Yes             Not employed, and not looking for work
# 1         No                 Not employed, but looking for work
# 2        Yes                                 Employed full-time
# 3         No                                 Employed full-time
# 4        Yes                                 Employed full-time
# ..       ...                                                ...
# 96       Yes                                 Employed full-time
# 97       Yes  Independent contractor, freelancer, or self-em...
# 98       Yes                                 Employed part-time
# 99       Yes                                 Employed full-time
# 100      Yes  Independent contractor, freelancer, or self-em...
#
# [101 rows x 2 columns]

# %%
# # print the hobbyist value from 0 to 100 using iloc
df.iloc[0:100,2]
# Out:
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 4     Yes
#      ...
# 95     No
# 96    Yes
# 97    Yes
# 98    Yes
# 99    Yes
# Name: Hobbyist, Length: 100, dtype: object

# %%
df.iloc[0:100,[2,5]]
# Out:
#    Hobbyist                                         Employment
# 0       Yes             Not employed, and not looking for work
# 1        No                 Not employed, but looking for work
# 2       Yes                                 Employed full-time
# 3        No                                 Employed full-time
# 4       Yes                                 Employed full-time
# ..      ...                                                ...
# 95       No                                 Employed full-time
# 96      Yes                                 Employed full-time
# 97      Yes  Independent contractor, freelancer, or self-em...
# 98      Yes                                 Employed part-time
# 99      Yes                                 Employed full-time
#
# [100 rows x 2 columns]

# %%
schema_df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_schema.csv')
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.loc[0:84,"QuestionText"]
# Out:
# 0     Randomized respondent ID number (not in order ...
# 1     Which of the following options best describes ...
# 2                               Do you code as a hobby?
# 3           How often do you contribute to open source?
# 4     How do you feel about the quality of open sour...
#                             ...
# 80    Which of the following do you currently identi...
# 81    Which of the following do you identify as? Ple...
# 82    Do you have any dependents (e.g., children, el...
# 83    How do you feel about the length of the survey...
# 84    How easy or difficult was this survey to compl...
# Name: QuestionText, Length: 85, dtype: object

# %%
schema_df.loc[0:10]
# Out:
#             Column                                       QuestionText
# 0       Respondent  Randomized respondent ID number (not in order ...
# 1       MainBranch  Which of the following options best describes ...
# 2         Hobbyist                            Do you code as a hobby?
# 3      OpenSourcer        How often do you contribute to open source?
# 4       OpenSource  How do you feel about the quality of open sour...
# 5       Employment  Which of the following best describes your cur...
# 6          Country          In which country do you currently reside?
# 7          Student  Are you currently enrolled in a formal, degree...
# 8          EdLevel  Which of the following best describes the high...
# 9   UndergradMajor  What was your main or most important field of ...
# 10        EduOther  Which of the following types of non-degree edu...

# %%
schema_df.loc[0:50,'QuestionText']
# Out:
# 0     Randomized respondent ID number (not in order ...
# 1     Which of the following options best describes ...
# 2                               Do you code as a hobby?
# 3           How often do you contribute to open source?
# 4     How do you feel about the quality of open sour...
# 5     Which of the following best describes your cur...
# 6             In which country do you currently reside?
# 7     Are you currently enrolled in a formal, degree...
# 8     Which of the following best describes the high...
# 9     What was your main or most important field of ...
# 10    Which of the following types of non-degree edu...
# 11    Approximately how many people are employed by ...
# 12    Which of the following describe you? Please se...
# 13    Including any education, how many years have y...
# 14    At what age did you write your first line of c...
# 15    How many years have you coded professionally (...
# 16    Overall, how satisfied are you with your caree...
# ...

# %%
schema_df=pd.read_csv('/content/drive/MyDrive/Tech Axis/survey_results_schema.csv',index_col='Column')
schema_df.head(3)
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?

# %%
schema_df.loc['MainBranch','QuestionText']
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."'
